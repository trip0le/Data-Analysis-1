# %% [markdown]
# # **Exploratory Data Analysis on a dataset called 'blood_pressure.csv'**
# Libraries used : **pandas** (to deal with dataframes in a dataset), **os** (to deal with file system), **matplotlib** (deals with basic plots) and **seaborn** (deals with advanced plots built on top of matplotlib).

# %%
import os
os.makedirs('./data', exist_ok=True)

# %%
import pandas as pd

# %%
file_path = './data/blood_pressure.csv'
data_frame = pd.read_csv(file_path)
data_frame
# Out:
#      patient     sex agegrp  bp_before  bp_after
# 0          1    Male  30-45        143       153
# 1          2    Male  30-45        163       170
# 2          3    Male  30-45        153       168
# 3          4    Male  30-45        153       142
# 4          5    Male  30-45        146       141
# ..       ...     ...    ...        ...       ...
# 115      116  Female    60+        152       152
# 116      117  Female    60+        161       152
# 117      118  Female    60+        165       174
# 118      119  Female    60+        149       151
# 119      120  Female    60+        185       163
#
# [120 rows x 5 columns]

# %%
data_frame.shape
# Out:
# (120, 5)

# %%
data_frame.describe()
# Out:
#           patient   bp_before    bp_after
# count  120.000000  120.000000  120.000000
# mean    60.500000  156.450000  151.358333
# std     34.785054   11.389845   14.177622
# min      1.000000  138.000000  125.000000
# 25%     30.750000  147.000000  140.750000
# 50%     60.500000  154.500000  149.500000
# 75%     90.250000  164.000000  161.000000
# max    120.000000  185.000000  185.000000

# %%
data_frame_sex = data_frame.groupby('sex')[['patient', 'agegrp', 'bp_before', 'bp_after']]

# %%
data_frame_sex.describe()
# Out:
#        patient                                                    bp_before  \
#          count  mean        std   min    25%   50%     75%    max     count
# sex
# Female    60.0  90.5  17.464249  61.0  75.75  90.5  105.25  120.0      60.0
# Male      60.0  30.5  17.464249   1.0  15.75  30.5   45.25   60.0      60.0
#
#                     ...                bp_after                                \
#               mean  ...     75%    max    count        mean        std    min
# sex                 ...
# Female  153.633333  ...  161.25  185.0     60.0  147.200000  11.742722  127.0
# Male    159.266667  ...  170.00  185.0     60.0  155.516667  15.243217  125.0
#
#
#           25%    50%     75%    max
# sex
# Female  138.0  146.0  152.00  178.0
# Male    145.0  158.5  164.75  185.0
#
# [2 rows x 24 columns]

# %%
data_frame_age = data_frame.groupby('agegrp')[['patient', 'sex', 'bp_before', 'bp_after']]

# %%
data_frame_age.describe()
# Out:
#        patient                                                    bp_before  \
#          count  mean        std   min    25%   50%     75%    max     count
# agegrp
# 30-45     40.0  40.5  30.938317   1.0  10.75  40.5   70.25   80.0      40.0
# 46-59     40.0  60.5  30.938317  21.0  30.75  60.5   90.25  100.0      40.0
# 60+       40.0  80.5  30.938317  41.0  50.75  80.5  110.25  120.0      40.0
#
#                  ...                bp_after                             \
#            mean  ...     75%    max    count     mean        std    min
# agegrp           ...
# 30-45   151.675  ...  157.25  176.0     40.0  144.325  11.893518  125.0
# 46-59   155.100  ...  161.25  185.0     40.0  150.775  14.502851  127.0
# 60+     162.575  ...  171.25  185.0     40.0  158.975  12.286093  138.0
#
#
#            25%    50%     75%    max
# agegrp
# 30-45   135.00  143.0  150.25  170.0
# 46-59   138.75  149.0  159.25  184.0
# 60+     148.75  159.0  167.00  185.0
#
# [3 rows x 24 columns]

# %%
data_frame_before = data_frame['bp_before']
data_frame_before.describe()
# Out:
# count    120.000000
# mean     156.450000
# std       11.389845
# min      138.000000
# 25%      147.000000
# 50%      154.500000
# 75%      164.000000
# max      185.000000
# Name: bp_before, dtype: float64

# %%
data_frame_after = data_frame['bp_after']
data_frame_after.describe()
# Out:
# count    120.000000
# mean     151.358333
# std       14.177622
# min      125.000000
# 25%      140.750000
# 50%      149.500000
# 75%      161.000000
# max      185.000000
# Name: bp_after, dtype: float64

# %%
# !pip install matplotlib seaborn --upgrade --quiet

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
before = data_frame['bp_before']
after = data_frame['bp_after']
age = data_frame['agegrp']

# %%
plt.title('Age wise distribution of before blood pressure');
plt.bar(age, before);
plt.xlabel('Age Group');
plt.ylabel('Before Blood Pressure');

# %%
plt.title('Age wise distribution of after blood pressure');
plt.bar(age, after);
plt.xlabel('Age Group');
plt.ylabel('After Blood Pressure');

# %%
plt.bar(age, before);
plt.bar(age, after);
plt.legend(['Before', 'After']);

# %%
sns.barplot(x='agegrp', y='bp_before', hue='sex', data = data_frame);

# %% [markdown]
# Analysis obtained :
# 1. **Before** and **after** treatment poses negligible effect on reducing blood pressure.
# 2. With age, blood pressure **increases**.
# 3. Males tend to have **higher** blood pressure than females.
